# %% [markdown]
# <a href="https://colab.research.google.com/github/hwan0309/tensorflow/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)

파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)

파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)

# %%
print(레모네이드.shape)
print(보스턴.shape)
print(아이리스.shape)
# Out:
# (6, 2)
# (506, 14)
# (150, 5)

# %%
#column name print
print(레모네이드.columns)
print(보스턴.columns)
print(아이리스.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')

# %%
독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)

독립 = 보스턴[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)

독립 = 아이리스[['꽃잎길이','꽃잎폭','꽃받침길이','꽃받침폭']]
종속 = 아이리스[['품종']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)
# (506, 13) (506, 1)
# (150, 4) (150, 1)

# %%
레모네이드.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
보스턴.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
아이리스.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %%
import tensorflow as tf
import pandas as pd

# %%
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
독립 = 데이터[['온도']]
종속 = 데이터[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
x = tf.keras.layers.Input(shape=[1])
y = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
# model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0022
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 5/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 7/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 8/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 9/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 10/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0022

# %%
model.predict(독립)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# array([[40.080654],
#        [42.054413],
#        [44.028168],
#        [46.001926],
#        [47.975685],
#        [49.94944 ]], dtype=float32)

# %%
model.predict([[15]])
# Out:
# 1/1 [==============================] - 0s 60ms/step
# array([[30.21187]], dtype=float32)

# %%
import pandas as pd
import tensorflow as tf

# %%
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
독립 = 데이터[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat']]
종속 = 데이터[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
x = tf.keras.layers.Input(shape=[13])
y = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=5000,verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1562
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.9589
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.4958
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1077
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.5231
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.2849
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.2318
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.6244
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.9408
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 24.2240

# %%
model.predict(독립[0:5])
# Out:
# 1/1 [==============================] - 0s 46ms/step
# array([[29.362198],
#        [24.178703],
#        [30.766136],
#        [29.429813],
#        [29.059208]], dtype=float32)

# %%
종속[5:10]
# Out:
#    medv
# 5  28.7
# 6  22.9
# 7  27.1
# 8  16.5
# 9  18.9

# %%
#모델수식확인
model.get_weights()
# Out:
# [array([[-0.09105838],
#         [ 0.04790218],
#         [-0.02493102],
#         [ 2.647965  ],
#         [-0.6297039 ],
#         [ 5.3522    ],
#         [-0.01133468],
#         [-1.0284237 ],
#         [ 0.19074778],
#         [-0.01055205],
#         [-0.484729  ],
#         [ 0.01257572],
#         [-0.4594476 ]], dtype=float32),
#  array([6.297223], dtype=float32)]

# %%
import tensorflow as tf
import pandas as pd

# %%
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)
아이리스.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %%
인코딩 = pd.get_dummies(아이리스)
인코딩.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_setosa  품종_versicolor  품종_virginica
# 0   5.1  3.5    1.4   0.2       True          False         False
# 1   4.9  3.0    1.4   0.2       True          False         False
# 2   4.7  3.2    1.3   0.2       True          False         False
# 3   4.6  3.1    1.5   0.2       True          False         False
# 4   5.0  3.6    1.4   0.2       True          False         False

# %%
독립=인코딩[['꽃잎길이','꽃잎폭','꽃받침길이','꽃받침폭']]
종속 = 인코딩[['품종_setosa','품종_versicolor','품종_virginica']]
print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
x = tf.keras.layers.Input(shape=[4])
y = tf.keras.layers.Dense(3, activation='softmax')(x)
model = tf.keras.models.Model(x,y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
model.fit(독립, 종속, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1934 - accuracy: 0.3467
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1833 - accuracy: 0.3467
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1724 - accuracy: 0.3467
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1625 - accuracy: 0.3467
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1524 - accuracy: 0.3467
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1428 - accuracy: 0.3467
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1329 - accuracy: 0.3467
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1241 - accuracy: 0.3467
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1132 - accuracy: 0.3467
# Epoch 10/100
# ...

# %%
model.predict(독립[0:5])
# Out:
# 1/1 [==============================] - 0s 47ms/step
# array([[0.6999388 , 0.27559897, 0.02446224],
#        [0.6932814 , 0.2712459 , 0.03547272],
#        [0.6753414 , 0.29347375, 0.03118489],
#        [0.65986496, 0.30093867, 0.03919632],
#        [0.6886937 , 0.28757334, 0.02373297]], dtype=float32)

# %%
print(종속[0:5])
# Out:
#    품종_setosa  품종_versicolor  품종_virginica
# 0       True          False         False
# 1       True          False         False
# 2       True          False         False
# 3       True          False         False
# 4       True          False         False
